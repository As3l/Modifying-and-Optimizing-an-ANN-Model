# %% [markdown]
# <a href="https://colab.research.google.com/github/As3l/Modifying-and-Optimizing-an-ANN-Model/blob/main/Modifying_and_Optimizing_an_ANN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

import os
import os.path
from os import path

import cv2
import PIL
import PIL.Image
from PIL import Image

import pathlib
from pathlib import Path
import imghdr
import shutil

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
# Out:
# /tmp/ipython-input-4047033521.py:15: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip 'drive/MyDrive/image_set.zip'
# Out:
# Archive:  drive/MyDrive/image_set.zip
#    creating: content/images/
#    creating: content/images/cat_images/
#   inflating: content/images/cat_images/000087.jpg
#   inflating: content/images/cat_images/000053.jpg
#   inflating: content/images/cat_images/000125.jpg
#   inflating: content/images/cat_images/000090.jpg
#   inflating: content/images/cat_images/000140.jpg
#   inflating: content/images/cat_images/000117.jpg
#   inflating: content/images/cat_images/000038.jpg
#   inflating: content/images/cat_images/000049.jpg
#   inflating: content/images/cat_images/000077.jpg
#   inflating: content/images/cat_images/000128.jpg
#   inflating: content/images/cat_images/000024.jpg
#   inflating: content/images/cat_images/000148.jpg
#   inflating: content/images/cat_images/000048.jpg
#   inflating: content/images/cat_images/000150.jpg
#   inflating: content/images/cat_images/000133.jpg
#   inflating: content/images/cat_images/000006.jpg
#   inflating: content/images/cat_images/000104.jpg
#   inflating: content/images/cat_images/000089.jpg
#   inflating: content/images/cat_images/000126.jpg
#   inflating: content/images/cat_images/000065.jpg
#   inflating: content/images/cat_images/000054.jpg
#   inflating: content/images/cat_images/000107.jpg
#   inflating: content/images/cat_images/000155.jpg
#   inflating: content/images/cat_images/000020.jpg
#   inflating: content/images/cat_images/000013.jpg
#   inflating: content/images/cat_images/000050.jpg
#   inflating: content/images/cat_images/000040.jpg
#   inflating: content/images/cat_images/000041.jpg
#   inflating: content/images/cat_images/000144.jpg
#   inflating: content/images/cat_images/000069.jpg
#   inflating: content/images/cat_images/000036.jpg
#   inflating: content/images/cat_images/000046.jpg
#   inflating: content/images/cat_images/000136.jpg
#   inflating: content/images/cat_images/000031.jpg
#   inflating: content/images/cat_images/000025.jpg
#   inflating: content/images/cat_images/000121.jpg
#   inflating: content/images/cat_images/000027.jpg
#   inflating: content/images/cat_images/000108.jpg
#   inflating: content/images/cat_images/000014.jpg
#   inflating: content/images/cat_images/000052.png
#   inflating: content/images/cat_images/000030.jpg
#   inflating: content/images/cat_images/000084.jpg
#   inflating: content/images/cat_images/000071.jpg
#   inflating: content/images/cat_images/000012.jpg
#   inflating: content/images/cat_images/000039.jpg
#   inflating: content/images/cat_images/000037.jpg
#   inflating: content/images/cat_images/000075.jpg
#   inflating: content/images/cat_images/000085.jpg
#   inflating: content/images/cat_images/000135.jpg
#   inflating: content/images/cat_images/000114.jpg
#   inflating: content/images/cat_images/000123.png
#   inflating: content/images/cat_images/000151.jpg
#   inflating: content/images/cat_images/000141.jpg
#   inflating: content/images/cat_images/000067.jpg
#   inflating: content/images/cat_images/000005.jpg
#   inflating: content/images/cat_images/000130.jpg
#   inflating: content/images/cat_images/000098.jpg
#   inflating: content/images/cat_images/000132.jpg
#   inflating: content/images/cat_images/000127.jpg
#   inflating: content/images/cat_images/000111.jpg
#   inflating: content/images/cat_images/000023.jpg
#   inflating: content/images/cat_images/000074.jpg
#   inflating: content/images/cat_images/000100.jpg
#   inflating: content/images/cat_images/000097.jpg
#   inflating: content/images/cat_images/000055.jpg
#   inflating: content/images/cat_images/000149.jpg
#   inflating: content/images/cat_images/000059.jpg
#   inflating: content/images/cat_images/000056.jpg
#   inflating: content/images/cat_images/000002.jpg
#   inflating: content/images/cat_images/000078.jpg
#   inflating: content/images/cat_images/000112.jpg
#   inflating: content/images/cat_images/000091.jpg
#   inflating: content/images/cat_images/000106.jpg
#   inflating: content/images/cat_images/000129.jpg
#   inflating: content/images/cat_images/000080.jpg
#   inflating: content/images/cat_images/000113.jpg
#   inflating: content/images/cat_images/000137.jpg
#   inflating: content/images/cat_images/000003.jpg
#   inflating: content/images/cat_images/000035.jpg
#   inflating: content/images/cat_images/000018.jpg
#   inflating: content/images/cat_images/000062.jpg
#   inflating: content/images/cat_images/000122.jpg
#   inflating: content/images/cat_images/000010.jpg
#   inflating: content/images/cat_images/000101.jpg
#   inflating: content/images/cat_images/000043.jpg
#   inflating: content/images/cat_images/000119.jpg
#   inflating: content/images/cat_images/000092.jpg
#   inflating: content/images/cat_images/000120.jpg
#   inflating: content/images/cat_images/000015.jpg
#   inflating: content/images/cat_images/000028.jpg
#   inflating: content/images/cat_images/000016.jpg
#   inflating: content/images/cat_images/000118.jpg
#   inflating: content/images/cat_images/000081.jpg
#   inflating: content/images/cat_images/000131.png
#   inflating: content/images/cat_images/000142.jpg
#   inflating: content/images/cat_images/000139.jpg
#   inflating: content/images/cat_images/000004.jpg
#   inflating: content/images/cat_images/000022.jpg
#   inflating: content/images/cat_images/000061.jpg
#   inflating: content/images/cat_images/000034.jpg
#   inflating: content/images/cat_images/000103.jpg
#   inflating: content/images/cat_images/000051.jpg
#   inflating: content/images/cat_images/000138.jpg
#   inflating: content/images/cat_images/000045.jpg
#   inflating: content/images/cat_images/000072.jpg
#   inflating: content/images/cat_images/000060.jpg
#   inflating: content/images/cat_images/000026.jpg
#   inflating: content/images/cat_images/000096.jpg
#   inflating: content/images/cat_images/000099.jpg
#   inflating: content/images/cat_images/000032.jpg
#   inflating: content/images/cat_images/000102.jpg
#   inflating: content/images/cat_images/000082.jpg
#   inflating: content/images/cat_images/000068.jpg
#   inflating: content/images/cat_images/000007.jpg
#   inflating: content/images/cat_images/000124.jpg
#   inflating: content/images/cat_images/000095.jpg
#   inflating: content/images/cat_images/000105.jpg
#   inflating: content/images/cat_images/000147.jpg
#   inflating: content/images/cat_images/000088.jpg
#   inflating: content/images/cat_images/000086.jpg
#   inflating: content/images/cat_images/000109.jpg
#   inflating: content/images/cat_images/000021.jpg
#   inflating: content/images/cat_images/000083.jpg
#   inflating: content/images/cat_images/000146.jpg
#   inflating: content/images/cat_images/000008.jpg
#   inflating: content/images/cat_images/000029.jpg
#   inflating: content/images/cat_images/000058.jpg
#   inflating: content/images/cat_images/000154.jpg
#   inflating: content/images/cat_images/000073.jpg
#   inflating: content/images/cat_images/000134.jpg
#   inflating: content/images/cat_images/000143.jpg
#   inflating: content/images/cat_images/000019.jpg
#   inflating: content/images/cat_images/000110.jpg
#   inflating: content/images/cat_images/000094.jpg
#   inflating: content/images/cat_images/000076.jpg
#   inflating: content/images/cat_images/000070.jpg
#   inflating: content/images/cat_images/000152.jpg
#   inflating: content/images/cat_images/000153.jpg
#   inflating: content/images/cat_images/000011.jpg
#   inflating: content/images/cat_images/000057.jpg
#   inflating: content/images/cat_images/000093.jpg
#   inflating: content/images/cat_images/000064.jpg
#   inflating: content/images/cat_images/000042.jpg
#   inflating: content/images/cat_images/000001.jpg
#   inflating: content/images/cat_images/000033.jpg
#   inflating: content/images/cat_images/000145.jpg
#   inflating: content/images/cat_images/000009.jpg
#   inflating: content/images/cat_images/000047.png
#   inflating: content/images/cat_images/000115.jpg
#   inflating: content/images/cat_images/000116.jpg
#   inflating: content/images/cat_images/000066.jpg
#   inflating: content/images/cat_images/000063.jpg
#   inflating: content/images/cat_images/000079.jpg
#   inflating: content/images/cat_images/000044.jpg
#   inflating: content/images/cat_images/000017.jpg
#    creating: content/images/snake_image/
#   inflating: content/images/snake_image/000087.jpg
#   inflating: content/images/snake_image/000053.jpg
#   inflating: content/images/snake_image/000125.jpg
#   inflating: content/images/snake_image/000090.jpg
#   inflating: content/images/snake_image/000117.jpg
#   inflating: content/images/snake_image/000038.jpg
#   inflating: content/images/snake_image/000049.jpg
#   inflating: content/images/snake_image/000077.jpg
#   inflating: content/images/snake_image/000128.jpg
#   inflating: content/images/snake_image/000024.jpg
#   inflating: content/images/snake_image/000048.jpg
#   inflating: content/images/snake_image/000047.jpg
#   inflating: content/images/snake_image/000133.jpg
#   inflating: content/images/snake_image/000006.jpg
#   inflating: content/images/snake_image/000104.jpg
#   inflating: content/images/snake_image/000089.jpg
#   inflating: content/images/snake_image/000126.jpg
#   inflating: content/images/snake_image/000065.jpg
#   inflating: content/images/snake_image/000066.png
#   inflating: content/images/snake_image/000107.jpg
#   inflating: content/images/snake_image/000020.jpg
#   inflating: content/images/snake_image/000013.jpg
#   inflating: content/images/snake_image/000031.png
#   inflating: content/images/snake_image/000050.jpg
#   inflating: content/images/snake_image/000040.jpg
#   inflating: content/images/snake_image/000041.jpg
#   inflating: content/images/snake_image/000069.jpg
#   inflating: content/images/snake_image/000036.jpg
#   inflating: content/images/snake_image/000046.jpg
#   inflating: content/images/snake_image/000025.jpg
#   inflating: content/images/snake_image/000121.jpg
#   inflating: content/images/snake_image/000027.jpg
#   inflating: content/images/snake_image/000108.jpg
#   inflating: content/images/snake_image/000014.jpg
#   inflating: content/images/snake_image/000097.png
#   inflating: content/images/snake_image/000052.png
#   inflating: content/images/snake_image/000030.jpg
#   inflating: content/images/snake_image/000084.jpg
#   inflating: content/images/snake_image/000071.jpg
#   inflating: content/images/snake_image/000039.jpg
#   inflating: content/images/snake_image/000037.jpg
#   inflating: content/images/snake_image/000075.jpg
#   inflating: content/images/snake_image/000085.jpg
#   inflating: content/images/snake_image/000067.jpg
#   inflating: content/images/snake_image/000005.jpg
#   inflating: content/images/snake_image/000130.jpg
#   inflating: content/images/snake_image/000098.jpg
#   inflating: content/images/snake_image/000132.jpg
#   inflating: content/images/snake_image/000127.jpg
#   inflating: content/images/snake_image/000111.jpg
#   inflating: content/images/snake_image/000023.jpg
#   inflating: content/images/snake_image/000074.jpg
#   inflating: content/images/snake_image/000100.jpg
#   inflating: content/images/snake_image/000114.png
#   inflating: content/images/snake_image/000131.jpg
#   inflating: content/images/snake_image/000055.jpg
#   inflating: content/images/snake_image/000059.jpg
#   inflating: content/images/snake_image/000056.jpg
#   inflating: content/images/snake_image/000002.jpg
#   inflating: content/images/snake_image/000078.jpg
#   inflating: content/images/snake_image/000112.jpg
#   inflating: content/images/snake_image/000091.jpg
#   inflating: content/images/snake_image/000106.jpg
#   inflating: content/images/snake_image/000129.jpg
#   inflating: content/images/snake_image/000080.png
#   inflating: content/images/snake_image/000113.jpg
#   inflating: content/images/snake_image/000003.jpg
#   inflating: content/images/snake_image/000035.jpg
#   inflating: content/images/snake_image/000018.jpg
#   inflating: content/images/snake_image/000062.jpg
#   inflating: content/images/snake_image/000010.jpg
#   inflating: content/images/snake_image/000101.jpg
#   inflating: content/images/snake_image/000043.jpg
#   inflating: content/images/snake_image/000119.jpg
#   inflating: content/images/snake_image/000092.jpg
#   inflating: content/images/snake_image/000120.jpg
#   inflating: content/images/snake_image/000015.jpg
#   inflating: content/images/snake_image/000028.jpg
#   inflating: content/images/snake_image/000016.jpg
#   inflating: content/images/snake_image/000118.jpg
#   inflating: content/images/snake_image/000081.jpg
#   inflating: content/images/snake_image/000123.jpg
#   inflating: content/images/snake_image/000004.jpg
#   inflating: content/images/snake_image/000022.jpg
#   inflating: content/images/snake_image/000061.jpg
#   inflating: content/images/snake_image/000034.jpg
#   inflating: content/images/snake_image/000103.jpg
#   inflating: content/images/snake_image/000051.jpg
#   inflating: content/images/snake_image/000045.jpg
#   inflating: content/images/snake_image/000072.jpg
#   inflating: content/images/snake_image/000122.png
#   inflating: content/images/snake_image/000060.jpg
#   inflating: content/images/snake_image/000026.jpg
#   inflating: content/images/snake_image/000096.jpg
#   inflating: content/images/snake_image/000099.jpg
#   inflating: content/images/snake_image/000032.jpg
#   inflating: content/images/snake_image/000102.jpg
#   inflating: content/images/snake_image/000082.jpg
#   inflating: content/images/snake_image/000068.jpg
#   inflating: content/images/snake_image/000007.jpg
#   inflating: content/images/snake_image/000124.jpg
#   inflating: content/images/snake_image/000054.png
#   inflating: content/images/snake_image/000095.jpg
#   inflating: content/images/snake_image/000105.jpg
#   inflating: content/images/snake_image/000088.jpg
#   inflating: content/images/snake_image/000086.jpg
#   inflating: content/images/snake_image/000109.jpg
#   inflating: content/images/snake_image/000021.jpg
#   inflating: content/images/snake_image/000083.jpg
#   inflating: content/images/snake_image/000008.jpg
#   inflating: content/images/snake_image/000134.png
#   inflating: content/images/snake_image/000029.jpg
#   inflating: content/images/snake_image/000058.jpg
#   inflating: content/images/snake_image/000073.jpg
#   inflating: content/images/snake_image/000019.jpg
#   inflating: content/images/snake_image/000110.jpg
#   inflating: content/images/snake_image/000094.jpg
#   inflating: content/images/snake_image/000076.jpg
#   inflating: content/images/snake_image/000070.jpg
#   inflating: content/images/snake_image/000011.jpg
#   inflating: content/images/snake_image/000057.jpg
#   inflating: content/images/snake_image/000093.jpg
#   inflating: content/images/snake_image/000064.jpg
#   inflating: content/images/snake_image/000042.jpg
#   inflating: content/images/snake_image/000001.jpg
#   inflating: content/images/snake_image/000033.jpg
#   inflating: content/images/snake_image/000009.jpg
#   inflating: content/images/snake_image/000115.jpg
#   inflating: content/images/snake_image/000116.jpg
#   inflating: content/images/snake_image/000063.jpg
#   inflating: content/images/snake_image/000079.jpg
#   inflating: content/images/snake_image/000044.jpg
#   inflating: content/images/snake_image/000017.jpg
#   inflating: content/images/snake_image/000012.png
#    creating: content/images/bird_images/
#   inflating: content/images/bird_images/000053.jpg
#   inflating: content/images/bird_images/000038.jpg
#   inflating: content/images/bird_images/000049.jpg
#   inflating: content/images/bird_images/000024.jpg
#   inflating: content/images/bird_images/000047.jpg
#   inflating: content/images/bird_images/000006.jpg
#   inflating: content/images/bird_images/000061.png
#   inflating: content/images/bird_images/000065.jpg
#   inflating: content/images/bird_images/000054.jpg
#   inflating: content/images/bird_images/000020.jpg
#   inflating: content/images/bird_images/000031.png
#   inflating: content/images/bird_images/000050.jpg
#   inflating: content/images/bird_images/000040.jpg
#   inflating: content/images/bird_images/000041.jpg
#   inflating: content/images/bird_images/000036.jpg
#   inflating: content/images/bird_images/000046.jpg
#   inflating: content/images/bird_images/000025.jpg
#   inflating: content/images/bird_images/000027.jpg
#   inflating: content/images/bird_images/000014.jpg
#   inflating: content/images/bird_images/000030.jpg
#   inflating: content/images/bird_images/000012.jpg
#   inflating: content/images/bird_images/000039.jpg
#   inflating: content/images/bird_images/000037.jpg
#   inflating: content/images/bird_images/000067.jpg
#   inflating: content/images/bird_images/000005.jpg
#   inflating: content/images/bird_images/000007.png
#   inflating: content/images/bird_images/000023.jpg
#   inflating: content/images/bird_images/000008.png
#   inflating: content/images/bird_images/000055.jpg
#   inflating: content/images/bird_images/000059.jpg
#   inflating: content/images/bird_images/000056.jpg
#   inflating: content/images/bird_images/000002.jpg
#   inflating: content/images/bird_images/000013.png
#   inflating: content/images/bird_images/000003.jpg
#   inflating: content/images/bird_images/000035.jpg
#   inflating: content/images/bird_images/000018.jpg
#   inflating: content/images/bird_images/000062.jpg
#   inflating: content/images/bird_images/000010.jpg
#   inflating: content/images/bird_images/000048.png
#   inflating: content/images/bird_images/000043.jpg
#   inflating: content/images/bird_images/000015.jpg
#   inflating: content/images/bird_images/000028.jpg
#   inflating: content/images/bird_images/000016.jpg
#   inflating: content/images/bird_images/000004.jpg
#   inflating: content/images/bird_images/000022.jpg
#   inflating: content/images/bird_images/000034.jpg
#   inflating: content/images/bird_images/000051.jpg
#   inflating: content/images/bird_images/000045.jpg
#   inflating: content/images/bird_images/000060.jpg
#   inflating: content/images/bird_images/000026.jpg
#   inflating: content/images/bird_images/000052.jpg
#   inflating: content/images/bird_images/000029.jpg
#   inflating: content/images/bird_images/000058.jpg
#   inflating: content/images/bird_images/000032.png
#   inflating: content/images/bird_images/000019.jpg
#   inflating: content/images/bird_images/000021.png
#   inflating: content/images/bird_images/000011.jpg
#   inflating: content/images/bird_images/000057.jpg
#   inflating: content/images/bird_images/000064.jpg
#   inflating: content/images/bird_images/000042.jpg
#   inflating: content/images/bird_images/000001.jpg
#   inflating: content/images/bird_images/000033.jpg
#   inflating: content/images/bird_images/000009.jpg
#   inflating: content/images/bird_images/000066.jpg
#   inflating: content/images/bird_images/000063.jpg
#   inflating: content/images/bird_images/000044.jpg
#   inflating: content/images/bird_images/000017.jpg
#    creating: content/images/frog_images/
#   inflating: content/images/frog_images/000166.jpg
#   inflating: content/images/frog_images/000087.jpg
#   inflating: content/images/frog_images/000053.jpg
#   inflating: content/images/frog_images/000125.jpg
#   inflating: content/images/frog_images/000090.jpg
#   inflating: content/images/frog_images/000140.jpg
#   inflating: content/images/frog_images/000117.jpg
#   inflating: content/images/frog_images/000167.jpg
#   inflating: content/images/frog_images/000049.jpg
#   inflating: content/images/frog_images/000071.png
#   inflating: content/images/frog_images/000077.jpg
#   inflating: content/images/frog_images/000128.jpg
#   inflating: content/images/frog_images/000098.png
#   inflating: content/images/frog_images/000038.png
#   inflating: content/images/frog_images/000024.jpg
#   inflating: content/images/frog_images/000165.jpg
#   inflating: content/images/frog_images/000048.jpg
#   inflating: content/images/frog_images/000150.jpg
#   inflating: content/images/frog_images/000151.png
#   inflating: content/images/frog_images/000133.jpg
#   inflating: content/images/frog_images/000006.jpg
#   inflating: content/images/frog_images/000104.jpg
#   inflating: content/images/frog_images/000161.jpg
#   inflating: content/images/frog_images/000089.jpg
#   inflating: content/images/frog_images/000126.jpg
#   inflating: content/images/frog_images/000065.jpg
#   inflating: content/images/frog_images/000168.jpg
#   inflating: content/images/frog_images/000066.png
#   inflating: content/images/frog_images/000054.jpg
#   inflating: content/images/frog_images/000107.jpg
#   inflating: content/images/frog_images/000155.jpg
#   inflating: content/images/frog_images/000020.jpg
#   inflating: content/images/frog_images/000013.jpg
#   inflating: content/images/frog_images/000156.jpg
#   inflating: content/images/frog_images/000050.jpg
#   inflating: content/images/frog_images/000040.jpg
#   inflating: content/images/frog_images/000041.jpg
#   inflating: content/images/frog_images/000144.jpg
#   inflating: content/images/frog_images/000069.jpg
#   inflating: content/images/frog_images/000036.jpg
#   inflating: content/images/frog_images/000046.jpg
#   inflating: content/images/frog_images/000136.jpg
#   inflating: content/images/frog_images/000031.jpg
#   inflating: content/images/frog_images/000025.jpg
#   inflating: content/images/frog_images/000121.jpg
#   inflating: content/images/frog_images/000027.jpg
#   inflating: content/images/frog_images/000108.jpg
#   inflating: content/images/frog_images/000014.jpg
#   inflating: content/images/frog_images/000164.jpg
#   inflating: content/images/frog_images/000030.jpg
#   inflating: content/images/frog_images/000084.jpg
#   inflating: content/images/frog_images/000012.jpg
#   inflating: content/images/frog_images/000039.jpg
#   inflating: content/images/frog_images/000037.jpg
#   inflating: content/images/frog_images/000075.jpg
#   inflating: content/images/frog_images/000085.jpg
#   inflating: content/images/frog_images/000135.jpg
#   inflating: content/images/frog_images/000114.jpg
#   inflating: content/images/frog_images/000123.png
#   inflating: content/images/frog_images/000141.jpg
#   inflating: content/images/frog_images/000067.jpg
#   inflating: content/images/frog_images/000005.jpg
#   inflating: content/images/frog_images/000132.jpg
#   inflating: content/images/frog_images/000127.jpg
#   inflating: content/images/frog_images/000007.png
#   inflating: content/images/frog_images/000111.jpg
#   inflating: content/images/frog_images/000023.jpg
#   inflating: content/images/frog_images/000074.jpg
#   inflating: content/images/frog_images/000100.jpg
#   inflating: content/images/frog_images/000097.jpg
#   inflating: content/images/frog_images/000131.jpg
#   inflating: content/images/frog_images/000055.jpg
#   inflating: content/images/frog_images/000149.jpg
#   inflating: content/images/frog_images/000059.jpg
#   inflating: content/images/frog_images/000056.jpg
#   inflating: content/images/frog_images/000002.jpg
#   inflating: content/images/frog_images/000078.jpg
#   inflating: content/images/frog_images/000112.jpg
#   inflating: content/images/frog_images/000106.jpg
#   inflating: content/images/frog_images/000129.jpg
#   inflating: content/images/frog_images/000080.jpg
#   inflating: content/images/frog_images/000148.png
#   inflating: content/images/frog_images/000113.jpg
#   inflating: content/images/frog_images/000137.jpg
#   inflating: content/images/frog_images/000003.jpg
#   inflating: content/images/frog_images/000160.jpg
#   inflating: content/images/frog_images/000035.jpg
#   inflating: content/images/frog_images/000018.jpg
#   inflating: content/images/frog_images/000062.jpg
#   inflating: content/images/frog_images/000122.jpg
#   inflating: content/images/frog_images/000010.jpg
#   inflating: content/images/frog_images/000101.jpg
#   inflating: content/images/frog_images/000043.jpg
#   inflating: content/images/frog_images/000119.jpg
#   inflating: content/images/frog_images/000092.jpg
#   inflating: content/images/frog_images/000120.jpg
#   inflating: content/images/frog_images/000015.jpg
#   inflating: content/images/frog_images/000028.jpg
#   inflating: content/images/frog_images/000016.jpg
#   inflating: content/images/frog_images/000159.jpg
#   inflating: content/images/frog_images/000118.jpg
#   inflating: content/images/frog_images/000081.jpg
#   inflating: content/images/frog_images/000142.jpg
#   inflating: content/images/frog_images/000139.jpg
#   inflating: content/images/frog_images/000004.jpg
#   inflating: content/images/frog_images/000022.jpg
#   inflating: content/images/frog_images/000061.jpg
#   inflating: content/images/frog_images/000034.jpg
#   inflating: content/images/frog_images/000103.jpg
#   inflating: content/images/frog_images/000051.jpg
#   inflating: content/images/frog_images/000138.jpg
#   inflating: content/images/frog_images/000045.jpg
#   inflating: content/images/frog_images/000072.jpg
#   inflating: content/images/frog_images/000060.jpg
#   inflating: content/images/frog_images/000026.jpg
#   inflating: content/images/frog_images/000096.jpg
#   inflating: content/images/frog_images/000052.jpg
#   inflating: content/images/frog_images/000099.jpg
#   inflating: content/images/frog_images/000032.jpg
#   inflating: content/images/frog_images/000102.jpg
#   inflating: content/images/frog_images/000082.jpg
#   inflating: content/images/frog_images/000068.jpg
#   inflating: content/images/frog_images/000124.jpg
#   inflating: content/images/frog_images/000011.png
#   inflating: content/images/frog_images/000095.jpg
#   inflating: content/images/frog_images/000158.jpg
#   inflating: content/images/frog_images/000105.jpg
#   inflating: content/images/frog_images/000147.jpg
#   inflating: content/images/frog_images/000088.jpg
#   inflating: content/images/frog_images/000086.jpg
#   inflating: content/images/frog_images/000109.jpg
#   inflating: content/images/frog_images/000021.jpg
#   inflating: content/images/frog_images/000083.jpg
#   inflating: content/images/frog_images/000146.jpg
#   inflating: content/images/frog_images/000008.jpg
#   inflating: content/images/frog_images/000029.jpg
#   inflating: content/images/frog_images/000058.jpg
#   inflating: content/images/frog_images/000154.jpg
#   inflating: content/images/frog_images/000073.jpg
#   inflating: content/images/frog_images/000134.jpg
#   inflating: content/images/frog_images/000143.jpg
#   inflating: content/images/frog_images/000019.jpg
#   inflating: content/images/frog_images/000110.jpg
#   inflating: content/images/frog_images/000162.jpg
#   inflating: content/images/frog_images/000091.png
#   inflating: content/images/frog_images/000094.jpg
#   inflating: content/images/frog_images/000130.png
#   inflating: content/images/frog_images/000076.jpg
#   inflating: content/images/frog_images/000070.jpg
#   inflating: content/images/frog_images/000152.jpg
#   inflating: content/images/frog_images/000153.jpg
#   inflating: content/images/frog_images/000057.jpg
#   inflating: content/images/frog_images/000093.jpg
#   inflating: content/images/frog_images/000064.jpg
#   inflating: content/images/frog_images/000042.jpg
#   inflating: content/images/frog_images/000001.jpg
#   inflating: content/images/frog_images/000033.jpg
#   inflating: content/images/frog_images/000145.jpg
#   inflating: content/images/frog_images/000009.jpg
#   inflating: content/images/frog_images/000047.png
#   inflating: content/images/frog_images/000115.jpg
#   inflating: content/images/frog_images/000163.jpg
#   inflating: content/images/frog_images/000116.jpg
#   inflating: content/images/frog_images/000063.jpg
#   inflating: content/images/frog_images/000157.jpg
#   inflating: content/images/frog_images/000079.jpg
#   inflating: content/images/frog_images/000044.jpg
#   inflating: content/images/frog_images/000017.jpg

# %%
# !unzip '/content/image_set.zip'
# Out:
# unzip:  cannot find or open /content/image_set.zip, /content/image_set.zip.zip or /content/image_set.zip.ZIP.

# %%
# You can check if the code ran correctly by checking the uploaded folders on Canvas
data_dir = 'content/images/'
# Take note of the folder you have created for invalid data
# This will be used later to check and filter out the "bad" images from our dataset
os.mkdir('content/invalid_images')

# %%
Image.open('content/images/frog_images/000001.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
def check_images(s_dir, ext_list):
    bad_images=[]
    bad_ext=[]
    s_list= os.listdir(s_dir)
    for klass in s_list:
        klass_path=os.path.join (s_dir, klass)
        print ('processing class directory ', klass)
        if os.path.isdir(klass_path):
            file_list=os.listdir(klass_path)
            for f in file_list:
                f_path=os.path.join (klass_path,f)
                index=f.rfind('.')
                ext=f[index+1:].lower()
                if ext not in ext_list:
                    print('file ', f_path, ' has an invalid extension ', ext)
                    bad_ext.append(f_path)
                if os.path.isfile(f_path):
                    try:
                        img=cv2.imread(f_path)
                        shape=img.shape
                    except:
                        print('file ', f_path, ' is not a valid image file')
                        bad_images.append(f_path)
                else:
                    print('*** fatal error, you a sub directory ', f, ' in class directory ', klass)
        else:
            print ('*** WARNING*** you have files in ', s_dir, ' it should only contain sub directories')
    return bad_images, bad_ext

# Change the folder path below to the folder of your data that you have uploaded
source_dir =r'content/images/'
# This is a test code to check if any files that you have downloaded have incorrect extensions
# The allowed extensions are listed below
good_exts=['jpg', 'png', 'jpeg', 'gif', 'bmp']
bad_file_list, bad_ext_list=check_images(source_dir, good_exts)
if len(bad_file_list) !=0:
    print('improper image files are listed below')
    for i in range (len(bad_file_list)):
        print (bad_file_list[i])
else:
    print(' no improper image files were found')
# Out:
# processing class directory  frog_images
# processing class directory  snake_image
# processing class directory  bird_images
# processing class directory  cat_images
#  no improper image files were found

# %%
# Change the folder path below to the folder of your data that you have uploaded
source_dir = "content/images/"
# Change the folder name below to the folder for invalid images that you created earlier
destination_folder_path = 'content/invalid_images'
# The image extensions below should list all the file extensions that are being used in your dataset
image_extensions = [".png", ".jpg", '.bmp', '.jpeg']
img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(source_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        destination_file_path = os.path.join(destination_folder_path, os.path.basename(filepath))
        if img_type is None:
            print(f"{filepath} is not an image")
            shutil.move(filepath, destination_file_path)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")
            shutil.move(filepath, destination_file_path)
# Out:
# content/images/frog_images/000120.jpg is a webp, not accepted by TensorFlow
# content/images/frog_images/000052.jpg is not an image
# content/images/frog_images/000042.jpg is a webp, not accepted by TensorFlow
# content/images/frog_images/000136.jpg is not an image
# content/images/snake_image/000035.jpg is not an image
# content/images/snake_image/000126.jpg is a webp, not accepted by TensorFlow
# content/images/snake_image/000060.jpg is a webp, not accepted by TensorFlow
# content/images/snake_image/000104.jpg is not an image
# content/images/snake_image/000038.jpg is not an image
# content/images/snake_image/000105.jpg is not an image
# content/images/bird_images/000018.jpg is not an image
# content/images/bird_images/000044.jpg is not an image
# content/images/bird_images/000035.jpg is a webp, not accepted by TensorFlow
# content/images/bird_images/000023.jpg is not an image
# content/images/bird_images/000010.jpg is not an image
# content/images/bird_images/000064.jpg is a webp, not accepted by TensorFlow
# content/images/bird_images/000063.jpg is not an image
# content/images/cat_images/000024.jpg is not an image
# content/images/cat_images/000018.jpg is not an image
# content/images/cat_images/000076.jpg is not an image
# content/images/cat_images/000002.jpg is not an image
# content/images/cat_images/000020.jpg is a webp, not accepted by TensorFlow
# content/images/cat_images/000096.jpg is not an image
# content/images/cat_images/000079.jpg is not an image
# content/images/cat_images/000099.jpg is a webp, not accepted by TensorFlow
# content/images/cat_images/000101.jpg is not an image
# content/images/cat_images/000143.jpg is not an image
# content/images/cat_images/000145.jpg is a webp, not accepted by TensorFlow
# content/images/cat_images/000140.jpg is a webp, not accepted by TensorFlow
# content/images/cat_images/000067.jpg is a webp, not accepted by TensorFlow
# content/images/cat_images/000061.jpg is a webp, not accepted by TensorFlow

# %%
batch_size = 32
img_height = 640
img_width = 640

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 493 files belonging to 4 classes.
# Using 395 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 493 files belonging to 4 classes.
# Using 98 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['bird_images', 'cat_images', 'frog_images', 'snake_image']

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# This should print out a range of values that resembles [0, 1]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  # Sequential Layer 1
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  # Sequential Layer 2
  layers.Conv2D(164, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  # Flatten Layers
  layers.Flatten(),
  # Output Layer
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# Just replace the "test_image_url" with the URL of the image you would like to test
bird = "https://cdn.britannica.com/10/250610-050-BC5CCDAF/Zebra-finch-Taeniopygia-guttata-bird.jpg"
# Change the "test_image_path" data with the name of the image that you will be testing against the model
test_image_path = tf.keras.utils.get_file('bird', origin=bird)

img = tf.keras.utils.load_img(
    test_image_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Downloading data from https://cdn.britannica.com/10/250610-050-BC5CCDAF/Zebra-finch-Taeniopygia-guttata-bird.jpg
# 119825/119825 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# This image most likely belongs to cat_images with a 99.82 percent confidence.
